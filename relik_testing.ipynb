# %%
cd NeurIPS_Materials
# Out:
# /teamspace/studios/this_studio/NeurIPS_Materials
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from relik import Relik
from relik.inference.data.objects import RelikOutput

relik = Relik.from_pretrained("sapienzanlp/relik-entity-linking-large")
relik_out: RelikOutput = relik("""The equiatomic 
CrMnFeCoNi alloy has become the benchmark material.""")
# Out:
#                 ___              __
#                /\_ \      __    /\ \
#  _ __     __   \//\ \    /\_\   \ \ \/'\
# /\`'__\ /'__`\   \ \ \   \/\ \   \ \ , <
# \ \ \/ /\  __/    \_\ \_  \ \ \   \ \ \\`\
#  \ \_\ \ \____\   /\____\  \ \_\   \ \_\ \_\
#   \/_/  \/____/   \/____/   \/_/    \/_/\/_/
#
#
#
# [2024-08-31 21:09:42,074] [INFO] [relik.inference.annotator.from_pretrained:700] [PID:3187] [RANK:0] Loading Relik from sapienzanlp/relik-entity-linking-large
# [2024-08-31 21:09:42,076] [INFO] [relik.inference.annotator.from_pretrained:701] [PID:3187] [RANK:0] {
#     '_target_': 'relik.inference.annotator.Relik',
#     'index': {
#         'span': {
#             '_target_': 'relik.retriever.indexers.inmemory.InMemoryDocumentIndex.from_pretrained',
#             'name_or_path': 'sapienzanlp/relik-retriever-e5-base-v2-aida-blink-wikipedia-index',
#         },
#     },
#     'metadata_fields': [],
#     'reader': {
# ...

# %% [markdown]
# ##### def print_limited_relik_output(relik_output):
#     print(f"RelikOutput(text='{relik_output.text}'")
#     print(f"tokens={relik_output.tokens}")
#
#     # Limit candidates to the first two
#     if hasattr(relik_output, 'candidates') and hasattr(relik_output.candidates, 'span'):
#         limited_candidates = relik_output.candidates.span[0][:2] if relik_output.candidates.span else []
#         print("candidates=Candidates(span=[")
#         for candidate in limited_candidates:
#             print(f"    {candidate}")
#         print("])")
#     print(")")
#
# print_limited_relik_output(relik_out)

# %%
relik_out
# Out:
# RelikOutput(text='The equiatomic \nCrMnFeCoNi alloy has become the benchmark material.', tokens=The equiatomic
# ...

# %%
from relik import Relik
from relik.inference.data.objects import RelikOutput

relik = Relik.from_pretrained("sapienzanlp/relik-entity-linking-large",device="cuda")
relik_out: RelikOutput = relik("""The multiprincipal-element
character of HEAs leads to some important effects that are
much less pronounced in conventional alloys.""")
# Out:
#                 ___              __
#                /\_ \      __    /\ \
#  _ __     __   \//\ \    /\_\   \ \ \/'\
# /\`'__\ /'__`\   \ \ \   \/\ \   \ \ , <
# \ \ \/ /\  __/    \_\ \_  \ \ \   \ \ \\`\
#  \ \_\ \ \____\   /\____\  \ \_\   \ \_\ \_\
#   \/_/  \/____/   \/____/   \/_/    \/_/\/_/
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# [2024-09-01 08:37:26,398] [INFO] [relik.inference.annotator.from_pretrained:700] [PID:41476] [RANK:0] Loading Relik from sapienzanlp/relik-entity-linking-large
# [2024-09-01 08:37:26,400] [INFO] [relik.inference.annotator.from_pretrained:701] [PID:41476] [RANK:0] {
#     '_target_': 'relik.inference.annotator.Relik',
#     'index': {
#         'span': {
# ...

# %%
relik_out
